# %% [markdown]
# <a href="https://colab.research.google.com/github/chenjeraichantelle-gif/In-class-Penguins/blob/main/In_Class_Assignment_DataViz_Penguins_(1)_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Learning Objectives
# - Create scatter, histogram, boxplot
# - Use color encoding and change bin sizes
# - Briefly interpret the plots in simple language

# %% [markdown]
# # In-Class Assignment: Data Visualization (Seaborn + Matplotlib)
#
# In this assignment, you will practice creating different types of visualizations and learn how to interpret what each plot shows. We will work with the built-in **penguins** dataset from the `seaborn` library.
#
# ### What You Will Do:
# 0. Load the dataset.
# 1. Create a scatter plot comparing **bill_length_mm** (x-axis) and **bill_depth_mm** (y-axis).
# 2. Add color coding to show differences across **species**.
# 3. Create two histograms of `bill_length_mm` with different bin sizes (10 and 30) and compare how the bin size changes the interpretation.
# 4. Create a boxplot of `body_mass_g` grouped by species to see how weight varies.
#
#
# ### Learning Goals:
# - Practice basic visualization functions in Seaborn/Matplotlib
# - Understand how visual choices (color, bins, grouping) affect interpretation
# - Explain data patterns clearly and simply
#
# Run each cell in order, fill in the code where indicated, and respond to the short-answer prompts below each plot.

# %% [markdown]
# ## 0) Setup

# %%
# Run it first.
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

sns.set_theme(style='whitegrid')
penguins = sns.load_dataset('penguins')
penguins = penguins.dropna()
penguins.head()  # preview
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 4       3450.0  Female
# 5       3650.0    Male
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['bill_length_mm'].plot(kind='hist', bins=20, title='bill_length_mm')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['bill_depth_mm'].plot(kind='hist', bins=20, title='bill_depth_mm')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['flipper_length_mm'].plot(kind='hist', bins=20, title='flipper_length_mm')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['body_mass_g'].plot(kind='hist', bins=20, title='body_mass_g')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('sex').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='bill_length_mm', y='bill_depth_mm', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='bill_depth_mm', y='flipper_length_mm', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='flipper_length_mm', y='body_mass_g', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['bill_length_mm'].plot(kind='line', figsize=(8, 4), title='bill_length_mm')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['bill_depth_mm'].plot(kind='line', figsize=(8, 4), title='bill_depth_mm')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['flipper_length_mm'].plot(kind='line', figsize=(8, 4), title='flipper_length_mm')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['body_mass_g'].plot(kind='line', figsize=(8, 4), title='body_mass_g')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_12['sex'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_12, x='bill_length_mm', y='sex', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_13['sex'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_13, x='bill_depth_mm', y='sex', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_14['sex'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_14, x='flipper_length_mm', y='sex', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_15['sex'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_15, x='body_mass_g', y='sex', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# ## 1–3) Scatter plot with color by species
# Create a scatter plot with:
# - **x =** `bill_length_mm`
# - **y =** `bill_depth_mm`
# - Color points by **species**
#
# Then add a short comment (2–3 sentences) describing the pattern(s) you see.

# %%
# TODO: Create the scatter plot here
import matplotlib.pyplot as plt
import seaborn as sns

sns.scatterplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', hue='species')

plt.show()

# %% [markdown]
# **Your interpretation (2–3 sentences):**
#
# the data is spread from the least 0 to 60 and a depth of about 5 to 22.
# The Adelie, Chinastrap and Gentoo are not scattered across each other. they seem to group at different points with different densities.

# %% [markdown]
# ## 4) Histogram with two different bin sizes
# Plot a histogram of `bill_length_mm` **twice**:
# - Once with **10 bins**
# - Once with **30 bins**
#
# Then write 1–2 sentences comparing what changes when you change the number of bins.

# %%
# TODO: Histogram with 10 bins
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(data=penguins, x='bill_length_mm', bins=10)
plt.show()

# %%
# TODO: Histogram with 30 bins
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(data=penguins,x= 'bill_length_mm', bins=30)
plt.show()

# %% [markdown]
# **Your comparison (1–2 sentences):**
#
# _Write your observations here._

# %% [markdown]
# ## 5) Boxplot of body mass by species
# Create a **boxplot** showing `body_mass_g` grouped by `species`.
# Then write 1–2 sentences summarizing which species are heavier/lighter on average.

# %%
# TODO: Boxplot of body mass by species
import matplotlib.pyplot as plt
import seaborn as sns

sns.boxplot(data=penguins, x='species', y='body_mass_g')
plt.show()

# %% [markdown]
# **Your summary
# The data is data is distinctly scattere, with similarities between Adelie specie and Chinastrap specie
